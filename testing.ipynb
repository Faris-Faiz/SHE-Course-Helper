# %%
import pandas as pd

# Replace 'your_file.xlsx' with the path to your Excel file
file_path = 'mayascrapingproject\\Scraped Courses (df2excel) - 202402141041.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

# %%
df
# Out:
#      FACULTY      CODE                                        COURSE NAME  \
# 0       FSSS   AIA1007                         INTRODUCTION TO PSYCHOLOGY
# 1       FSSS   AIA1013                          COMMUNITY AND ENVIRONMENT
# 2       FSSS   AIA2002  CONTEMPORARY SOCIAL THOUGHT  (ONLY FOR ANTHROP...
# 3       FSSS   AIA2002  CONTEMPORARY SOCIAL THOUGHT  (ONLY FOR SPECIAL...
# 4       FSSS   AIA2008  CROSS-CULTURAL ETHNOGRAPHY (ONLY FOR ANTHROPOL...
# ...      ...       ...                                                ...
# 5294   FSKTM   WQF7005    DATA PRIVACY AND ARTIFICIAL INTELLIGENCE ETHICS
# 5295   FSKTM   WQF7010                            ROBOTICS AND AUTOMATION
# 5296   FSKTM   WQF7011                                COGNITIVE COMPUTING
# 5297   FSKTM   WQF7023           ARTIFICIAL INTELLIGENCE RESEARCH PROJECT
# 5298   FSKTM  WXGB6321                                     WEB PUBLISHING
#
#      OCCURRENCE   MEDIUM  REGISTERED  CAPACITY   FULL  \
# 0             1  LECTURE           0        80  False
# 1             1  LECTURE           0        80  False
# 2             1  LECTURE           0        20  False
# 3             2  LECTURE           0        20  False
# 4             1  LECTURE           0        10  False
# ...         ...      ...         ...       ...    ...
# 5294          1  LECTURE           0        50  False
# 5295          1  LECTURE           0        30  False
# 5296          1  LECTURE           0        30  False
# 5297         P1  LECTURE           0        60  False
# 5298          1  LECTURE           0      2423  False
#
#                                                  WEEK  \
# 0     7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 1     7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 2     7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 3     7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 4     7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# ...                                               ...
# 5294  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 5295  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 5296  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 5297                                              NaN
# 5298  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
#
#                                   DAY                             MENTOR  \
# 0        Tuesday  2:00 PM  -  4:00 PM                 MOHD AWANG B IDRIS
# 1         Monday  2:00 PM  -  4:00 PM  SYED ABDUL RAZAK BIN SAYED MAHADI
# 2      Wednesday  2:00 PM  -  4:00 PM          KAMAL SOLHAIMI BIN FADZIL
# 3      Wednesday  2:00 PM  -  4:00 PM          KAMAL SOLHAIMI BIN FADZIL
# 4      Wednesday  4:00 PM  -  6:00 PM               WELYNE JEFFREY JEHOM
# ...                               ...                                ...
# 5294    Thursday  6:00 PM  -  9:00 PM                NORISMA BINTI IDRIS
# 5295      Friday  6:00 PM  -  9:00 PM      ZATI HAKIM BINTI AZIZUL HASAN
# 5296      Friday  6:00 PM  -  9:00 PM          SAMEEM BINTI ABDUL KAREEM
# 5297                              NaN     UNAIZAH HANUM BINTI OBAIDELLAH
# 5298  Wednesday  10:00 AM  -  4:00 PM                                NaN
#
#                            ROOM
# 0     Dewan Kuliah F FSSS (400)
# 1     Dewan Kuliah C FSSS (115)
# 2         Auditorium FSSS (150)
# 3         Auditorium FSSS (150)
# 4         Auditorium FSSS (150)
# ...                         ...
# 5294  Makmal Mikro 6 FSKTM (45)
# 5295  Bilik Kuliah 2 FSKTM (50)
# 5296  Makmal Mikro 2 FSKTM (37)
# 5297                        NaN
# 5298                        NaN
#
# [5299 rows x 12 columns]

# %%
def map_cluster(df):
    # Map clusters based on course code prefix
    cluster_mapping = {
        'GB': 1,
        'GD': 2,
        'GF': 3,
        'GQ': 4
    }

    # Apply mapping function to each row
    df['CLUSTER'] = df['CODE'].apply(lambda x: cluster_mapping.get(x[:2], None))

    # Filter out rows with no matching cluster and create new DataFrame
    she_course_df = df[df['CLUSTER'].notna()].copy()

    return she_course_df

# %%
she_course_df = map_cluster(df)

# %%
she_course_df
# Out:
#      FACULTY     CODE                                        COURSE NAME  \
# 503     FSSS  GBA0021  APPRECIATING LITERATURE   (This course will be...
# 504     FSSS  GBA0022               AN OVERVIEW OF EUROPEAN CIVILISATION
# 505     FSSS  GBA0048  MODERNIZATION PROCESS OF EAST ASIA (ENGLISH LA...
# 506     FSSS  GDA0007                  PSYCHOLOGY POSITIVE IN DAILY LIFE
# 507     FSSS  GQA0018                             GENDER AND CITIZENSHIP
# ...      ...      ...                                                ...
# 4942   FSKTM  GFW0030              BUSINESS ANALYTICS FOR DECISION MAKER
# 4943   FSKTM  GFW0030              BUSINESS ANALYTICS FOR DECISION MAKER
# 4944   FSKTM  GFW0031                    COMPUTER NETWORKS FOR EVERYBODY
# 4945   FSKTM  GFW0031                    COMPUTER NETWORKS FOR EVERYBODY
# 4946   FSKTM  GFW0031                    COMPUTER NETWORKS FOR EVERYBODY
#
#      OCCURRENCE   MEDIUM  REGISTERED  CAPACITY   FULL  \
# 503           1   ONLINE           0       100  False
# 504           1  LECTURE           0        30  False
# 505           1   ONLINE           0       100  False
# 506           1   ONLINE           0       100  False
# 507           1   ONLINE           0        35  False
# ...         ...      ...         ...       ...    ...
# 4942         1M   ONLINE           0        10  False
# 4943          2   ONLINE           0        50  False
# 4944          1   ONLINE           0        50  False
# 4945         1M   ONLINE           0        10  False
# 4946          2   ONLINE           0        50  False
#
#                                                  WEEK  \
# 503   7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 504   7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 505   7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 506   7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 507   7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# ...                                               ...
# 4942  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 4943  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 4944  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 4945  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
# 4946  7, 8, 9, 10, 11, 13, 14, 15, 16, 17, 18, 19, 20
#
#                                    DAY                            MENTOR  \
# 503     Wednesday  2:00 PM  -  4:00 PM                    VANDANA SAXENA
# 504      Monday  10:00 AM  -  12:00 PM  NUR DAYANA BINTI MOHAMED ARIFFIN
# 505     Tuesday  10:00 AM  -  12:00 PM                   PARK CHANG KYOO
# 506     Thursday  12:00 PM  -  2:00 PM                ASBAH BINTI RAZALI
# 507     Tuesday  10:00 AM  -  12:00 PM               RUHANA BINTI PADZIL
# ...                                ...                               ...
# 4942   Wednesday  9:00 AM  -  11:00 AM          NOR LIYANA BT MOHD SHUIB
# 4943    Wednesday  2:00 PM  -  4:00 PM        NORJIHAN BINTI ABDUL GHANI
# 4944       Monday  2:00 PM  -  4:00 PM                 ISMAIL BIN AHMEDY
# 4945       Monday  2:00 PM  -  4:00 PM                 ISMAIL BIN AHMEDY
# 4946  Wednesday  10:00 AM  -  12:00 PM                 ISMAIL BIN AHMEDY
#
#                            ROOM  CLUSTER
# 503                         NaN      1.0
# 504   Bilik Seminar 3 FSSS (35)      1.0
# 505                         NaN      1.0
# 506                         NaN      2.0
# 507                         NaN      4.0
# ...                         ...      ...
# 4942                        NaN      3.0
# 4943                        NaN      3.0
# 4944                        NaN      3.0
# 4945                        NaN      3.0
# 4946                        NaN      3.0
#
# [177 rows x 13 columns]

# %%
len(df)
# Out:
# 5299
